# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sg6_1 = [[0, 8, 11, 14, 17, 20], [0, 0.058, 0.831, 0.602, 0.757, 0.593], [0.068, 0.071, 0.019, 0.034, 0.029, 0.034]]
sg6_2 = [[0, 8, 11, 14, 17, 20], [0, 0.186, 0.969, 0.857, 0.936, 0.894], [0.129, 0.082, 0.012, 0.015, 0.016, 0.012]]
sg6_4 = [[0, 8, 11, 14, 17, 20], [0, 0.458, 0.985, 0.969, 0.979, 0.954], [0.118, 0.126, 0.002, 0.015, 0.007, 0.013]]

# %%
ax = plt.axes()
plt.errorbar(sg6_1[0], sg6_1[1], sg6_1[2],
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '1nM sgRNA DNA')
plt.errorbar(sg6_2[0], sg6_2[1], sg6_2[2], 
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '2nM sgRNA DNA')
plt.errorbar(sg6_4[0], sg6_4[1], sg6_4[2],
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '4nM sgRNA DNA')
sns.set(font_scale = 2)
sns.set_style("whitegrid")
ax.set_title('TXTL CRISPRi sgRNA DNA titration', fontsize = 37)
plt.ylabel('Fraction of Silenced Reporters', fontsize = 37)
plt.xlabel('sgRNA length (bp)', fontsize = 40)
plt.rcParams["figure.figsize"] = (15, 12)
plt.xticks(range(0, 21, 2), fontsize = 40)
plt.yticks(fontsize = 42)
plt.ylim(-0.14, 1.05)
first_legend = plt.legend(loc= [0.47, 0.015], fancybox =True, borderpad = 0.7, framealpha =1,
                         fontsize = 36, edgecolor = 'black', shadow = 'True')
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 3
plt.show()
