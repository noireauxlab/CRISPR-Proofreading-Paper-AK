# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
c206_2 = [[0, 8, 11, 14, 17, 19, 20], [149.33, 354.33, 145.67, 284.00, 246.33, 908.33, 622.67], [43.31, 115.7, 40.75, 39.16, 49.58, 186.52, 153.89]]
c206_4 = [[0, 8, 11, 14, 17, 19, 20], [184, 803.33, 202, 354.67, 266.33, 1169.67, 819.67], [29.34, 352.5, 43.25, 54.97, 30.92, 82.03, 70.09]]
c206_6 = [[0, 8, 11, 14, 17, 19, 20], [209.33, 656.33, 265.67, 378, 274, 1051.33, 615.67], [40.11, 159.4, 37.26, 66.52, 31.88, 98.57, 106.27]]

# %%
ax = plt.axes()
plt.errorbar(c206_2[0], c206_2[1], c206_2[2], 
              capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '2nM pJF144.206')
plt.errorbar(c206_4[0], c206_4[1], c206_4[2],
              capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '4nM pJF144.206')
plt.errorbar(c206_6[0], c206_6[1], c206_6[2], 
              capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '6nM pJF144.206')
sns.set(font_scale = 2)
sns.set_style("whitegrid")
ax.set_title('TXTL dCas9 CRISPRa pJF144.206 scRNA DNA titration', fontsize = 37)
plt.ylabel('mRFP (a.u.)', fontsize = 40)
plt.xlabel('scRNA length (bp)', fontsize = 40)
plt.rcParams["figure.figsize"] = (15, 12)
plt.xticks(range(0, 21, 2), fontsize = 40)
plt.yticks(fontsize = 40)
first_legend = plt.legend(loc=[0.43, 0.72], fancybox =True, borderpad = 0.4, framealpha =1,
                         fontsize = 34, edgecolor = 'black', shadow = 'True')
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 3
plt.show()
