# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
c306_2 = [[0, 8, 11, 14, 17, 20], [-4.66, 176, 33.67, 498.34, 508.34, 1173.34], [53.72, 49.50, 58.01, 85.73, 112.88, 90.56]]
c306_4 = [[0, 8, 11, 14, 17, 20], [46.083, 494, 142.58, 625.34, 76.58, 230.83], [62.71, 125.70, 75.99, 73.09, 81.13, 53.74]]
c306_6 = [[0, 8, 11, 14, 17, 20], [28.83, 267.083, 112.34, 1031.34, 552.08, 1892.34], [61.76, 70.18, 62.67, 230, 96.31, 83.69]]

# %%
ax = plt.axes()
plt.errorbar(c306_2[0], c306_2[1], c306_2[2],
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '2nM scRNA DNA')
plt.errorbar(c306_4[0], c306_4[1], c306_4[2], 
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '4nM scRNA DNA')
plt.errorbar(c306_6[0], c306_6[1], c306_6[2],
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '6nM scRNA DNA')
sns.set(font_scale = 2)
sns.set_style("whitegrid")
ax.set_title('TXTL CRISPRa scRNA DNA titration', fontsize = 37)
plt.ylabel('mRFP (a.u.)', fontsize = 40)
plt.xlabel('scRNA length (bp)', fontsize = 40)
plt.rcParams["figure.figsize"] = (15, 12)
plt.xticks(range(0, 21, 2), fontsize = 40)
plt.yticks(fontsize = 40)
first_legend = plt.legend(loc='upper left', fancybox =True, borderpad = 0.7, framealpha =1,
                         fontsize = 36, edgecolor = 'black', shadow = 'True')
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 3
plt.show()
