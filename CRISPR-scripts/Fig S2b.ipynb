# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
c406_2 = [[0, 11, 14, 17, 18, 19, 20], [81.67, 85.67, 63.67, 92, 578.67, 599.67, 265.33], [26.67, 49.91, 22.77, 21.27, 118.82, 114.59, 109.41]]
c406_4 = [[0, 11, 14, 17, 18, 19, 20], [111.67, 162.33, 69, 99.67, 383.67, 437, 408.67], [46.54, 38.22, 32.78, 31.17, 32.68, 33.07, 56.35]]
c406_6 = [[0, 11, 14, 17, 18, 19, 20], [120, 91, 83.33, 64, 239.33, 333.67, 256.33], [64.19, 37.74, 39.59, 39.27, 79.63, 99.7, 106.2]]

# %%
ax = plt.axes()
plt.errorbar(c406_2[0], c406_2[1], c406_2[2], 
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '2nM pJF144.406')
plt.errorbar(c406_4[0], c406_4[1], c406_4[2],
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '4nM pJF144.406')
plt.errorbar(c406_6[0], c406_6[1], c406_6[2], 
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '6nM pJF144.406')
sns.set(font_scale = 2)
sns.set_style("whitegrid")
ax.set_title('TXTL dCas9 CRISPRa pJF144.406 scRNA DNA titration', fontsize = 37)
plt.ylabel('mRFP (a.u.)', fontsize = 40)
plt.xlabel('scRNA length (bp)', fontsize = 40)
plt.rcParams["figure.figsize"] = (15, 12)
plt.xticks(range(0, 21, 2), fontsize = 40)
plt.yticks(fontsize = 40)
first_legend = plt.legend(loc='upper left', fancybox =True, borderpad = 0.7, framealpha =1,
                         fontsize = 34, edgecolor = 'black', shadow = 'True')
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 3
plt.show()
