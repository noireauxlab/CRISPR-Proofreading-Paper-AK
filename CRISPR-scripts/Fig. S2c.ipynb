# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sg9_1 = [[0, 8, 11, 14, 17, 20], [0, -0.053, 0.393, 0.245, 0.438, 0.548], [0.063, 0.085, 0.048, 0.096, 0.03, 0.037]]
sg9_2 = [[0, 8, 11, 14, 17, 20], [0, -0.032, 0.690, 0.504, 0.780, 0.786], [0.092, 0.072, 0.028, 0.049, 0.033, 0.017]]
sg9_4 = [[0, 8, 11, 14, 17, 20], [0, -0.086, 0.769, 0.534, 0.685, 0.733], [0.086, 0.074, 0.025, 0.054, 0.046, 0.033]]

# %%
ax = plt.axes()
plt.errorbar(sg9_1[0], sg9_1[1], sg9_1[2], 
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '1nM sg9')
plt.errorbar(sg9_2[0], sg9_2[1], sg9_2[2],
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '2nM sg9')
plt.errorbar(sg9_4[0], sg9_4[1], sg9_4[2], 
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '4nM sg9')
sns.set(font_scale = 2)
sns.set_style("whitegrid")
ax.set_title('TXTL dCas9 CRISPRi sg9 sgRNA DNA titration', fontsize = 37)
plt.ylabel('Ratio of Silenced Reporters', fontsize = 40)
plt.xlabel('sgRNA length (bp)', fontsize = 40)
plt.rcParams["figure.figsize"] = (15, 12)
plt.xticks(range(0, 21, 2), fontsize = 40)
plt.yticks(fontsize = 40)
first_legend = plt.legend(loc='upper left', fancybox =True, borderpad = 0.7, framealpha =1,
                         fontsize = 36, edgecolor = 'black', shadow = 'True')
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 3
plt.show()
