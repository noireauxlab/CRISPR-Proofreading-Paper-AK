# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
j206_1 = [[0, 8, 11, 14, 17, 19, 20], [178, 1079, 210, 477, 440, 180, 143], [11, 111, 45, 69, 71, 26, 7]]
j206_2 = [[0, 8, 11, 14, 17, 19, 20], [216, 1005, 280, 659, 546, 198, 155], [27, 177, 40, 91, 56, 62, 24]]
j206_3 = [[0, 8, 11, 14, 17, 19, 20], [213, 965, 312, 655, 493, 152, 199], [11, 105, 48, 56, 19, 15, 26]]

# %%
ax = plt.axes()
plt.errorbar(j206_1[0], j206_1[1], j206_1[2], 
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '1nM pJF144.206')
plt.errorbar(j206_2[0], j206_2[1], j206_2[2],
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '2nM pJF144.206')
plt.errorbar(j206_3[0], j206_3[1], j206_3[2], 
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '3nM pJF144.206')
sns.set(font_scale = 2)
sns.set_style("whitegrid")
ax.set_title('TXTL Cas9 CRISPRa pJF144.206 scRNA DNA titration', fontsize = 37)
plt.ylabel('mRFP (a.u.)', fontsize = 40)
plt.xlabel('scRNA length (bp)', fontsize = 40)
plt.rcParams["figure.figsize"] = (15, 12)
plt.xticks(range(0, 21, 2), fontsize = 40)
plt.yticks(fontsize = 40)
first_legend = plt.legend(loc=[0.51, 0.73], fancybox =True, borderpad = 0.4, framealpha =1,
                         fontsize = 36, edgecolor = 'black', shadow = 'True')
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 3
plt.show()
