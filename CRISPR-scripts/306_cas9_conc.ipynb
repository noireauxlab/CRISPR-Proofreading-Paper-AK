# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
j306_1 = [[0, 8, 11, 14, 18, 19, 20], [1101, 7882, 9833, 11330, 428, 319, 657], [91, 576, 1650, 1084, 34, 61, 38]]
j306_2 = [[0, 8, 11, 14, 18, 19, 20], [1372, 5500, 10266, 9044, 368, 312, 805], [17, 327, 1209, 394, 39, 16, 198]]
j306_3 = [[0, 8, 11, 14, 18, 19, 20], [1505, 6192, 11410, 10484, 299, 294, 837], [149, 927, 1168, 571, 63, 17, 198]]

# %%
ax = plt.axes()
plt.errorbar(j306_1[0], j306_1[1], j306_1[2], 
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '1nM pJF144.306')
plt.errorbar(j306_2[0], j306_2[1], j306_2[2],
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '2nM pJF144.306')
plt.errorbar(j306_3[0], j306_3[1], j306_3[2], 
             capsize = 7, elinewidth = 4, marker ='.', lw = 4,
             capthick = 4, ms = '35', label = '3nM pJF144.306')
sns.set(font_scale = 2)
sns.set_style("whitegrid")
ax.set_title('TXTL Cas9 CRISPRa 144.306 scRNA DNA range', fontsize = 37)
plt.ylabel('mRFP (a.u.)', fontsize = 40)
plt.xlabel('scRNA length (bp)', fontsize = 40)
plt.rcParams["figure.figsize"] = (15, 12)
plt.xticks(range(0, 21, 2), fontsize = 40)
plt.yticks(fontsize = 40)
first_legend = plt.legend(loc=[0.01, 0.74], fancybox =True, borderpad = 0.4, framealpha =1,
                         fontsize = 36, edgecolor = 'black', shadow = 'True')
plt.rcParams["axes.edgecolor"] = "black"
plt.rcParams["axes.linewidth"] = 3
plt.show()
